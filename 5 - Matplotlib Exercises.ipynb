# %% [markdown]
# # <u>Matplotlib Exercises.
#
# ***NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP.***
#
# # <u>Exercises.
#
# Follow the instructions to recreate the plots using this data:
#
# ## <u>Data.

# %%
import numpy as np

x = np.arange(0, 100)
y = x * 2
z = x ** 2

# %% [markdown]
# **Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt

# plt.show() if we aren't using Jupyter Notebook.

# %% [markdown]
# ## Exercise 1
#
# **Follow along with these steps:**
#
# ***Create a figure object called fig using plt.figure()***
#
# ***Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.***
#
# ***Plot (x,y) on that axes and set the labels and titles to match the plot below:***

# %%
fig = plt.figure(figsize = (12, 6))

ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, y, color = 'blue', lw = 1, ls = '-', marker = 'o', markersize = 3, markerfacecolor = 'red')
ax.set_title('x v/s y')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')

plt.show()

# %% [markdown]
# ## Exercise 2
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure(figsize = (4, 4))

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2])

plt.show()

# %% [markdown]
# **Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig = plt.figure(figsize = (12, 6))

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2])

ax1.plot(x, y, color = 'red', lw = 1, ls = '-', marker = 'o', markersize = 3, markerfacecolor = 'yellow')
ax1.set_title('Bigger plot')
ax1.set_xlabel('X axis')
ax1.set_ylabel('Y axis')

ax2.plot(x, y, color = 'blue', lw = 1, ls = '-')
ax2.set_title('Insert plot')

plt.show()

# %% [markdown]
# ## Exercise 3
#
# **Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure(figsize = (4, 4))

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.2, 0.5, 0.4, 0.4])

# %% [markdown]
# **Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig = plt.figure(figsize = (12, 6))

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.2, 0.5, 0.4, 0.4])

ax1.plot(x, z, color = 'red', lw = 1, ls = '-', marker = 'o', markersize = 3, markerfacecolor = 'purple')
ax1.set_title('Bigger plot')
ax1.set_xlabel('X')
ax1.set_ylabel('Z')

ax2.plot(x, y, color = 'blue', lw = 1, ls = '-', marker = 's', markersize = 7, markerfacecolor = 'yellow')
ax2.set_title('Zoom')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_xlim([20, 22])
ax2.set_ylim([30, 50])

plt.show()

# %% [markdown]
# ## Exercise 4
#
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
(fig, axes) = plt.subplots(nrows = 1, ncols = 2, figsize = (12, 6))

# %% [markdown]
# **Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
(fig, axes) = plt.subplots(nrows = 1, ncols = 2)

axes[0].plot(x, y, color = 'blue', lw = 3, ls = '--')
axes[0].set_title('x v/s y')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')

axes[1].plot(x, z, color = 'red', lw = 3, ls = '-')
axes[1].set_title('x v/s z')
axes[1].set_xlabel('X')
axes[1].set_ylabel('Z')

plt.tight_layout()

# %% [markdown]
# **See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
(fig, axes) = plt.subplots(nrows = 1, ncols = 2, figsize = (12, 4))

axes[0].plot(x, y, color = 'blue', lw = 3, ls = '-')
axes[0].set_title('x v/s y')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')

axes[1].plot(x, z, color = 'red', lw = 3, ls = '--')
axes[1].set_title('x v/s z')
axes[1].set_xlabel('X')
axes[1].set_ylabel('Z')

plt.tight_layout()

# %% [markdown]
# ---
